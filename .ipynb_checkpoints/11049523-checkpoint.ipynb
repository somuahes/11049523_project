# %% [markdown]
# # Peggy Esinam Somuah

# %% [markdown]
# ## 11049523
# ## CPEN

# %%
import numpy as np

# %%
import matplotlib.pyplot as mp

# %%
import pandas as pd

# %%
dataset=pd.read_csv('red_wine.csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# ### Before using any visualization strategies or deriving conclusions from the red_wine dataset, we have to do the following
#
#  * Clean up the data;
#  * Store the processed dataset in a new variable
#  * Search the processed dataset for any new information.

# %% [markdown]
# #### removing rows with missing entries

# %%
new_data=dataset.dropna()

# %%
new_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # The ranges for categorizing residual sugar values

# %%
low_range = (1.0, 5.9)
medium_range = (6.0, 9.9)
high_range = (10.0, 14.0)

# %% [markdown]
# ##### Categorize residual sugar values based on the defined ranges

# %%
dataset['sugar_category'] = pd.cut(dataset['residual sugar'], bins=[0] + list(high_range) + [float('inf')], labels=['low', 'medium', 'high'])

# %% [markdown]
# ##### Determine how many times each category occurs.

# %%
sugar_distribution = dataset['sugar_category'].value_counts()

# %% [markdown]
# ### Creating a bar graph

# %%
mp.figure(figsize=(8, 6))
mp.bar(sugar_distribution.index, sugar_distribution, width=0.3, color='black')
mp.title('Distribution of Residual Sugar in Red Wine Dataset')
mp.xlabel('Sugar Category')
mp.ylabel('Frequency')
mp.xticks(range(3), ['low', 'medium', 'high'])
mp.ylim(0, 14)
mp.show()

# %% [markdown]
# ### ANALYSIS MADE FROM THE GRAPH ABOVE:
# - A significant distribution of residual sugar contents, classified as Low (1.0-5.9), Medium (6.0-9.9), and High (10.0-14.0) in the red wine dataset is displayed.
#
# - With a notable proportion having less, most red wines have low residual sugar. The levels of medium and low wines are moderate and low, respectively.
#
# - By offering substantial information regarding the prevalence of different residual sugar levels within the dataset, this distribution insight aids in the understanding of common characteristics and preferences connected with red wines.

# %%
new_dataset = dataset.dropna()

# %%
data = new_data['quality'].value_counts()

# %% [markdown]
# ### CREATING PIE CHART

# %%
mp.figure(figsize=(8, 6))
mp.pie(data, labels=data.index, autopct='%1.0f%%', startangle=140)
mp.title('the distribution of quality of red wine')
mp.axis('equal')  
mp.show()

# %% [markdown]
# ## Analysis of the Above Pie Chart
# - Red wines fall on a complex and varied quality spectrum, ranging from 5.0 to 8.0.
# - As can be seen from the pie chart, 42% and 40%, respectively, of red wines fall into this category.
# - Only 1% of the distribution is made up of red wines with the lowest quality ratings, 3.0 and 8.0, while 13% is made up of those with the highest grade, 7.0.
# - As can be seen from the pie chart, the majority of red wines are in the moderate to above-average quality group.

# %%
new_dataset = dataset.dropna()

# %% [markdown]
# #### Count the occurrences in each category

# %%
sugar_distribution = dataset['residual sugar'].value_counts()

# %% [markdown]
# ### Create a bar chart

# %%
fig, ax = mp.subplots(figsize=(10, 5))
ax.bar(sugar_distribution.index, sugar_distribution, color=['blue', 'red', 'gold', 'yellow', 'black'])
ax.set_title('Distribution of Residual Sugar in Red Wine')
ax.set_xlabel('Residual Sugar (g/L)')
ax.set_ylabel('Frequency')
mp.show()

# %% [markdown]
# #### Analysis Of The Bar Graph Above
# - The graph above shows that there are numerous entries for the residual sugar in the red wine.
#
# Because of this, I classified them into labels because the graph above is a little difficult to read;
#
# - 'low' for residual sugar levels between 1.0 and 5.9
#
# - 'Medium' for the range of residual sugars (6.0–9.9)
#
# - 'high' for residual sugar levels between 9.9 and 13.9.

# %% [markdown]
# #### Plotting a bar graph for alcohol content

# %%
alcohol_content = new_dataset['alcohol']

# %%
mp.figure(figsize=(10, 6))
mp.hist(alcohol_content, bins=15, color='red', edgecolor='white')
mp.xlabel('Alcohol Content')
mp.ylabel('Frequency')
mp.title('Alcohol Content Distribution in Red Wine')
mp.show()

# %% [markdown]
# #### Analysis Of The Above Bar Graph:
# -From the graph, it is evident that:
# - the bulk of red wine has an alcohol concentration between 9.0 and 10.0
# - this is followed by 10.0, 10.5, 9.0, and so on.
# -  A significant fraction of the red wine has an alcohol content between 9.0 and 10.0.
